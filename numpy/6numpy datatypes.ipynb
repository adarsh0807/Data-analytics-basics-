# %%
import numpy as np

# %%
arr = np.array([12, 23, 3, 4, 54, 7, 45])

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr.astype('float32')
# Out:
# array([12., 23.,  3.,  4., 54.,  7., 45.], dtype=float32)

# %%
arr.nbytes
# Out:
# 56

# %%
arrcom = np.array([1 + 2j, 3 + 4j, 5 + 6j])

# %%
arrcom
# Out:
# array([1.+2.j, 3.+4.j, 5.+6.j])
