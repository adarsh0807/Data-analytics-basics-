# %%
import numpy as np

# %%
arr = np.array([2, 56, 5, 7, 45])

# %%
np.mean(arr)
# Out:
# np.float64(23.0)

# %%
np.std(arr)
# Out:
# np.float64(22.777181564012697)

# %%
np.var(arr)
# Out:
# np.float64(518.8)

# %%
np.min(arr)
# Out:
# np.int64(2)

# %%
np.max(arr)
# Out:
# np.int64(56)

# %%
np.sum(arr)
# Out:
# np.int64(115)

# %%
np.prod(arr)
# Out:
# np.int64(176400)

# %%
np.median(arr)
# Out:
# np.float64(7.0)

# %%
np.argmin(arr)
# Out:
# np.int64(0)

# %%
np.argmax(arr)
# Out:
# np.int64(1)

# %%
np.corrcoef(arr)
# Out:
# np.float64(1.0)

# %%
np.unique(arr)
# Out:
# array([ 2,  5,  7, 45, 56])

# %%
np.diff(arr)
# Out:
# array([ 54, -51,   2,  38])

# %%
np.cumsum(arr)
# Out:
# array([  2,  58,  63,  70, 115])

# %%
np.linspace(0, 10, 5)
# Out:
# array([ 0. ,  2.5,  5. ,  7.5, 10. ])

# %%
np.log(arr)
# Out:
# array([0.69314718, 4.02535169, 1.60943791, 1.94591015, 3.80666249])

# %%
np.exp(arr)
# Out:
# array([7.38905610e+00, 2.09165950e+24, 1.48413159e+02, 1.09663316e+03,
#        3.49342711e+19])

# %%
np.percentile(arr,50)
# Out:
# np.float64(7.0)
