# %%
import numpy as np

# %%
kri = np.array([[1,5,9],[4,8,7],[6,5,7]])

# %%
kri
# Out:
# array([[1, 5, 9],
#        [4, 8, 7],
#        [6, 5, 7]])

# %%
kri.shape
# Out:
# (3, 3)

# %%
ada = np.array([1.1,2.2,3.3])

# %%
ada
# Out:
# array([1.1, 2.2, 3.3])

# %%
x = ada.astype("int")

# %%
x
# Out:
# array([1, 2, 3])

# %%
fn = np.array([1,2,3,4,5,6])

# %%
fn
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
fn[[1,3,5]]
# Out:
# array([2, 4, 6])

# %%
reshaped = kri.reshape(9,1)

# %%
reshaped
# Out:
# array([[1],
#        [5],
#        [9],
#        [4],
#        [8],
#        [7],
#        [6],
#        [5],
#        [7]])

# %%
bool = np.array([81,55,45,51,1,2,3,4,5,6])
bool
# Out:
# array([81, 55, 45, 51,  1,  2,  3,  4,  5,  6])

# %%
bool[bool>50]
# Out:
# array([81, 55, 51])
