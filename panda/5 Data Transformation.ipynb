# %%
import pandas as pd

# %%
df = pd.read_csv("bollywood_data.csv")

# %%
df
# Out:
#                     Actor                      Film  Year          Genre  \
# 0          Shah Rukh Khan                   Pathaan  2023         Action
# 1             Salman Khan           Tiger Zinda Hai  2017         Action
# 2              Aamir Khan                    Dangal  2016      Biography
# 3           Ranbir Kapoor                Brahmastra  2022        Fantasy
# 4           Ranveer Singh                 Padmaavat  2018     Historical
# 5      Ayushmann Khurrana                 Andhadhun  2018       Thriller
# 6           Rajkummar Rao                     Stree  2018  Horror Comedy
# 7          Hrithik Roshan                       War  2019         Action
# 8            Akshay Kumar                Good Newwz  2019         Comedy
# 9           Kartik Aaryan         Bhool Bhulaiyaa 2  2022  Horror Comedy
# 10  Shushant Singh Rajput                  Chichore  2019         Comedy
# 11          Vicky Kaushal  Uri: The Surgical Strike  2019         Action
#
# ...

# %%
df.sort_values('IMDb')
# Out:
#                     Actor                      Film  Year          Genre  \
# 3           Ranbir Kapoor                Brahmastra  2022        Fantasy
# 9           Kartik Aaryan         Bhool Bhulaiyaa 2  2022  Horror Comedy
# 1             Salman Khan           Tiger Zinda Hai  2017         Action
# 7          Hrithik Roshan                       War  2019         Action
# 4           Ranveer Singh                 Padmaavat  2018     Historical
# 8            Akshay Kumar                Good Newwz  2019         Comedy
# 0          Shah Rukh Khan                   Pathaan  2023         Action
# 6           Rajkummar Rao                     Stree  2018  Horror Comedy
# 11          Vicky Kaushal  Uri: The Surgical Strike  2019         Action
# 5      Ayushmann Khurrana                 Andhadhun  2018       Thriller
# 2              Aamir Khan                    Dangal  2016      Biography
# 10  Shushant Singh Rajput                  Chichore  2019         Comedy
#
# ...

# %%
df.sort_values('IMDb', ascending=False)
# Out:
#                     Actor                      Film  Year          Genre  \
# 10  Shushant Singh Rajput                  Chichore  2019         Comedy
# 2              Aamir Khan                    Dangal  2016      Biography
# 5      Ayushmann Khurrana                 Andhadhun  2018       Thriller
# 11          Vicky Kaushal  Uri: The Surgical Strike  2019         Action
# 6           Rajkummar Rao                     Stree  2018  Horror Comedy
# 0          Shah Rukh Khan                   Pathaan  2023         Action
# 4           Ranveer Singh                 Padmaavat  2018     Historical
# 8            Akshay Kumar                Good Newwz  2019         Comedy
# 7          Hrithik Roshan                       War  2019         Action
# 1             Salman Khan           Tiger Zinda Hai  2017         Action
# 9           Kartik Aaryan         Bhool Bhulaiyaa 2  2022  Horror Comedy
# 3           Ranbir Kapoor                Brahmastra  2022        Fantasy
#
# ...

# %%
df2 = df.sort_values(['IMDb', 'Year']).copy()

# %%
#df2.reset_index(drop = True, inplace=True)

# %%
df2.sort_index()
# Out:
#                     Actor                      Film  Year          Genre  \
# 0          Shah Rukh Khan                   Pathaan  2023         Action
# 1             Salman Khan           Tiger Zinda Hai  2017         Action
# 2              Aamir Khan                    Dangal  2016      Biography
# 3           Ranbir Kapoor                Brahmastra  2022        Fantasy
# 4           Ranveer Singh                 Padmaavat  2018     Historical
# 5      Ayushmann Khurrana                 Andhadhun  2018       Thriller
# 6           Rajkummar Rao                     Stree  2018  Horror Comedy
# 7          Hrithik Roshan                       War  2019         Action
# 8            Akshay Kumar                Good Newwz  2019         Comedy
# 9           Kartik Aaryan         Bhool Bhulaiyaa 2  2022  Horror Comedy
# 10  Shushant Singh Rajput                  Chichore  2019         Comedy
# 11          Vicky Kaushal  Uri: The Surgical Strike  2019         Action
#
# ...

# %%
df2["Rank"] = df["IMDb"].rank(ascending=False, method="dense")

# %%
df2
# Out:
#                     Actor                      Film  Year          Genre  \
# 3           Ranbir Kapoor                Brahmastra  2022        Fantasy
# 9           Kartik Aaryan         Bhool Bhulaiyaa 2  2022  Horror Comedy
# 1             Salman Khan           Tiger Zinda Hai  2017         Action
# 7          Hrithik Roshan                       War  2019         Action
# 4           Ranveer Singh                 Padmaavat  2018     Historical
# 8            Akshay Kumar                Good Newwz  2019         Comedy
# 0          Shah Rukh Khan                   Pathaan  2023         Action
# 6           Rajkummar Rao                     Stree  2018  Horror Comedy
# 11          Vicky Kaushal  Uri: The Surgical Strike  2019         Action
# 5      Ayushmann Khurrana                 Andhadhun  2018       Thriller
# 2              Aamir Khan                    Dangal  2016      Biography
# 10  Shushant Singh Rajput                  Chichore  2019         Comedy
#
# ...

# %%
df2 = df2[["Actor", "Year", "Genre", "Film", "IMDb", "BoxOffice(Cr)"]]

# %%
df2.sort_index()
# Out:
#                     Actor  Year          Genre                      Film  \
# 0          Shah Rukh Khan  2023         Action                   Pathaan
# 1             Salman Khan  2017         Action           Tiger Zinda Hai
# 2              Aamir Khan  2016      Biography                    Dangal
# 3           Ranbir Kapoor  2022        Fantasy                Brahmastra
# 4           Ranveer Singh  2018     Historical                 Padmaavat
# 5      Ayushmann Khurrana  2018       Thriller                 Andhadhun
# 6           Rajkummar Rao  2018  Horror Comedy                     Stree
# 7          Hrithik Roshan  2019         Action                       War
# 8            Akshay Kumar  2019         Comedy                Good Newwz
# 9           Kartik Aaryan  2022  Horror Comedy         Bhool Bhulaiyaa 2
# 10  Shushant Singh Rajput  2019         Comedy                  Chichore
# 11          Vicky Kaushal  2019         Action  Uri: The Surgical Strike
#
# ...
