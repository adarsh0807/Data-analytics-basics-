# %%
import pandas as pd

# %%
s1 = pd.Series([46, 45, 65, 67, 23, 56])

# %%
s
# Out:
# 0    46
# 1    45
# 2    65
# 3    67
# 4    23
# 5    56
# dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s2 = pd.Series([46, 45, 65, 67, 23, 56], index=["harry", "john", "nunu", "kuku", "chuhu", "laila"])

# %%
s2
# Out:
# harry    46
# john     45
# nunu     65
# kuku     67
# chuhu    23
# laila    56
# dtype: int64

# %%
data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [25, 30, 35],
    "City": ["New York", "London", "Paris"]
}

# %%
data
# Out:
# {'Name': ['Alice', 'Bob', 'Charlie'],
#  'Age': [25, 30, 35],
#  'City': ['New York', 'London', 'Paris']}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   30    London
# 2  Charlie   35     Paris

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'City'], dtype='object')
